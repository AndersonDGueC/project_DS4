# %%
import os
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
print("Team 10")
# Out:
# Team 10

# %% [markdown]
# We'll do a EDA (exploring data analysis) of list customer dataset

# %%
#DataSet Brazilian Ecommerce
# 03- olist_customers_dataset.csv
df_olist_customer = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_customers_dataset.csv")
df_olist_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
#DataSet Brazilian Ecommerce
# 04- olist_geolocation_dataset.csv
df_olist_geo = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_geolocation_dataset.csv")
df_olist_geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
#DataSet Brazilian Ecommerce
# 05- olist_order_items_dataset.csv
df_olist_order = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_order_items_dataset.csv")
df_olist_order.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_olist_order['price'].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
len(df_olist_order['order_id'].unique())
# Out:
# 98666

# %%
#DataSet Brazilian Ecommerce
# 06- olist_order_payments_dataset.csv
df_olist_order_pay = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_order_payments_dataset.csv")
df_olist_order_pay.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
#DataSet Brazilian Ecommerce
# 07- olist_order_reviews_dataset.csv
df_olist_reviews = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_order_reviews_dataset.csv")
df_olist_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ## Table  and grafic of order status ##

# %%
#DataSet Brazilian Ecommerce
# 08- olist_orders_dataset.csv
df_olist_orders = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_orders_dataset.csv")
df_olist_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df_olist_orders.shape
# Out:
# (99441, 8)

# %%
x=list(df_olist_orders['order_status'])

plt.hist(x, bins=5)
plt.xticks(rotation=45)
plt.show()
#type_status_order=list(order_status["index"])
#type_status_order
#order_status.plot.hist(type_status_order)

# %%
df_olist_order.shape
# Out:
# (112650, 7)

# %%
len(df_olist_orders['order_id'].unique())
sns.boxplot()
# Out:
# 99441

# %%
#DataSet Brazilian Ecommerce
# 09- olist_products_dataset.csv
df_olist_products = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_products_dataset.csv")
df_olist_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
len(df_olist_products['product_id'].unique())
# Out:
# 32951

# %%
dict_products={}
column_new=[]
product_id=list(df_olist_products['product_id'])
for i, id_p in enumerate(product_id):
    dict_products[id_p]=df_olist_products['product_category_name'][i]
     
for d in list(df_olist_order['product_id']):
    column_new.append(dict_products[d])
        
#column_new
new_df_olist_order=df_olist_order.copy()
new_df_olist_order=new_df_olist_order[['order_id','order_item_id','product_id','shipping_limit_date','price','freight_value']]
new_df_olist_order['product_category_name']=column_new
new_df_olist_order.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id  shipping_limit_date   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  2017-09-19 09:45:35   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  2017-05-03 11:05:13  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  2018-01-18 14:48:30  199.00
# 3  7634da152a4610f1595efa32f14722fc  2018-08-15 10:10:18   12.99
# 4  ac6c3623068f30de03045865e4e10089  2017-02-13 13:57:51  199.90
#
#    freight_value product_category_name
# 0          13.29            cool_stuff
# 1          19.93              pet_shop
# 2          17.87      moveis_decoracao
# 3          12.79            perfumaria
# 4          18.14    ferramentas_jardim

# %%
new_df_olist_order.groupby(['product_category_name'])['product_id'].count().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  11115
# beleza_saude                      9670
# esporte_lazer                     8641
# moveis_decoracao                  8334
# informatica_acessorios            7827
#                                  ...
# cds_dvds_musicais                   14
# la_cuisine                          14
# pc_gamer                             9
# fashion_roupa_infanto_juvenil        8
# seguros_e_servicos                   2
# Name: product_id, Length: 73, dtype: int64

# %%
new_df_olist_order.groupby(['product_category_name'])['order_id'].value_counts()
# Out:
# product_category_name      order_id
# agro_industria_e_comercio  2cc9089445046817a7539d90805e6e5a    6
#                            877448ea783b661571099dbd672a4fa3    5
#                            010b143d83a59b355cd5a75c0f0fd785    4
#                            a3a09d0a201027720550355df943b598    4
#                            fd566cfe4efd75cdc3ac93a0e1010248    3
#                                                               ..
# utilidades_domesticas      ffb47bf24e3f64dc0a2059a9181b976a    1
#                            ffbae9b91be0cb7c3cc9a38a35c29210    1
#                            ffde92ba447b33a47d1c04d203f10f41    1
#                            ffef9e1de5dd07b397b373f9bb72cccf    1
#                            fffc94f6ce00a00581880bf54a75a037    1
# Name: order_id, Length: 98019, dtype: int64

# %%
len(df_olist_products['product_category_name'].unique())
# Out:
# 74

# %% [markdown]
# We'll do describe in df_olist_products:

# %%
df_olist_products.describe()
# Out:
#        product_name_lenght  product_description_length  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
df_olist_products.shape
# Out:
# (32951, 9)

# %%
df_olist_products['product_category_name'].describe()
# Out:
# count               32341
# unique                 73
# top       cama_mesa_banho
# freq                 3029
# Name: product_category_name, dtype: object

# %%
#DataSet Brazilian Ecommerce
# 10- olist_sellers_dataset.csv
df_olist_sellers = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/olist_sellers_dataset.csv")
df_olist_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
#DataSet Brazilian Ecommerce
# 11- product_category_name_translation.csv
df_olist_sellers = pd.read_csv("./e-commerce/datasets/brazilian-ecommerce/product_category_name_translation.csv")
df_olist_sellers.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
translate_name_english={}
name_orig=list(df_olist_sellers['product_category_name'])
for cont, name_p in enumerate(name_orig):
    translate_name_english[name_p]=df_olist_sellers['product_category_name_english'][cont]

#translate_name_english['nan']='NaN'

# %% [markdown]
# ## Table of price and product category name ##

# %%
dict_products={}
column_new=[]
product_id=list(df_olist_products['product_id'])
for i, id_p in enumerate(product_id):
    dict_products[id_p]=df_olist_products['product_category_name'][i]
     
for d in list(df_olist_order['product_id']):
    column_new.append(dict_products[d])
        
#column_new
new_df_olist_order=df_olist_order.copy()
new_df_olist_order=new_df_olist_order[['order_id','order_item_id','product_id','shipping_limit_date','price','freight_value']]
new_df_olist_order['product_category_name']=column_new
new_df_olist_order.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id  shipping_limit_date   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  2017-09-19 09:45:35   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  2017-05-03 11:05:13  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  2018-01-18 14:48:30  199.00
# 3  7634da152a4610f1595efa32f14722fc  2018-08-15 10:10:18   12.99
# 4  ac6c3623068f30de03045865e4e10089  2017-02-13 13:57:51  199.90
#
#    freight_value product_category_name
# 0          13.29            cool_stuff
# 1          19.93              pet_shop
# 2          17.87      moveis_decoracao
# 3          12.79            perfumaria
# 4          18.14    ferramentas_jardim

# %%
new_df_olist_order.groupby(['product_category_name','price'])['order_id'].count()
# Out:
# product_category_name      price
# agro_industria_e_comercio  12.99       1
#                            13.00       1
#                            19.50      13
#                            21.99       9
#                            22.00       6
#                                       ..
# utilidades_domesticas      1449.80     1
#                            1489.00     1
#                            1799.00     1
#                            2338.08     3
#                            6735.00     1
# Name: order_id, Length: 17472, dtype: int64

# %%
productcat_vs_meanprice=new_df_olist_order.groupby(['product_category_name'])['price'].mean().sort_values( ascending=True)
productcat_vs_meanprice
# Out:
# product_category_name
# casa_conforto_2                  25.342333
# flores                           33.637576
# fraldas_higiene                  40.194615
# cds_dvds_musicais                52.142857
# alimentos_bebidas                54.602446
#                                   ...
# instrumentos_musicais           281.616000
# agro_industria_e_comercio       342.124858
# eletrodomesticos_2              476.124958
# portateis_casa_forno_e_cafe     624.285658
# pcs                            1098.340542
# Name: price, Length: 73, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,30))
productcat_vs_meanprice.plot(kind='barh', ax=ax, legend=True, title="Product category-Price average", grid=True, color='g')
plt.xticks(rotation=90);

# %%
productcat_freightmean=new_df_olist_order.groupby(['product_category_name'])['freight_value'].mean().sort_values(ascending=True)
# Out:
# product_category_name
# agro_industria_e_comercio    27.564151
# alimentos                    14.256922
# alimentos_bebidas            16.215791
# artes                        19.354880
# artes_e_artesanato           15.422083
#                                ...
# sinalizacao_e_seguranca      32.702613
# tablets_impressao_imagem     14.773494
# telefonia                    15.669041
# telefonia_fixa               17.567462
# utilidades_domesticas        20.986374
# Name: freight_value, Length: 73, dtype: float64

# %%
prodductcat_freightmean.plot(kind="barh", )

# %%
len(new_df_olist_order['order_id'].unique())
# Out:
# 98666

# %%
#column_new_translate=[]
#product_name_por=list(new_df_olist_order['product_category_name'].astype(str))
#for name_2 in product_name_por:
    #print(type(name_2))
    #column_new_translate.append(translate_name_english[name_2])

# %% [markdown]
# ## Graphic of type of category most purchased ##

# %%
count_product=new_df_olist_order['product_category_name'].value_counts().reset_index(name="count")
#l.plot.hist()
plot_product=count_product.plot(x='index',y='count',title='type of category most purchased', rot=90)
_=plt.ylabel("purchase of frequency")
_=plt.xlabel("category product")

# %% [markdown]
# ## Table category of products, order status and times ##

# %%
order_item_beta=new_df_olist_order.groupby('order_id')['order_item_id'].count().reset_index()
dict_item={}
for i, var in enumerate(list(order_item_beta['order_id'])):
    dict_item[var]=order_item_beta['order_item_id'][i]

dict_item
# Out:
# {'00010242fe8c5a6d1ba2dd792cb16214': 1,
#  '00018f77f2f0320c557190d7a144bdd3': 1,
#  '000229ec398224ef6ca0657da4fc703e': 1,
#  '00024acbcdf0a6daa1e931b038114c75': 1,
#  '00a3a334aec7455a6d3319981499a3da': 1,
#  '00a3f1ef430d3984dece2f39d6cbf431': 1,
#  '00a4d94df1c9757661679b2f4bd6d311': 1,
#  '00a57dfbb049fbaae10763e2cf15f797': 3,
#  '00a690becda145533fa5a54daa7b6ad5': 1,
#  '00a77f9cc25b05b2004752593d7b8888': 1,
#  '00a843f5a80c7aea894c558acc29f513': 1,
#  '00a870c6c06346e85335524935c600c0': 1,
#  '00a9536682ecb394a3794c1608200803': 1,
#  '00a99c50fdff7e36262caba33821875a': 1,
#  '00aa423621f35a9ca6c6240f275b0640': 1,
#  '00ab1aba567dfebdc39caa4e7ca2f1b2': 1,
#  '00ab210695a17fe10e6b23616ae5bc97': 1,
#  '00ab3a43bda739029ffce95d3b2fb56c': 1,
#  '00ab9fa91aafa3d881164b0da48999aa': 1,
#  '00ac05fe0fc047c54418098eb64e3aaa': 1,
#  '00ac2a1ec784f71feeb7ba1e5959750d': 1,
#  '00ace652c8a5072670f30674e5f19844': 1,
#  '00ad1a02d4d9decad15c7e8f8a9470cc': 1,
#  '00ae7a8b4936674ebb701d4a23719a79': 1,
#  '00af3d9ddff7f256e83d79247dbe1a9f': 1,
#  '00af53fdc2002f5b6a8f16db648e003b': 1,
#  '00b12f4674177ef40c4bdb034138c843': 1,
#  '00b1861aeb89afa498404c684148a619': 2,
#  '00b2d2f2b5f7b98e6b1828764660134e': 1,
#  '00b30bb163474583c14db1689259cf4d': 1,
#  '00b402e8a76d3da83714c52d3977cc2d': 1,
#  '00b44ba3d7c4a5e9a9ebafef9150781d': 1,
#  '00b47ee856118583dbec7d1f9b18d847': 1,
#  '00b4846d477a7baf5d4e47970bc08c7e': 1,
#  '00b4a910f64f24dbcac04fe54088a443': 1,
#  '00b4c651133c06fb175123a492f1cac3': 1,
#  '00b5e1c770b1868ec1b6b726be3aa9b9': 1,
#  '00b676b01c289cc661c6f7732492771a': 1,
#  '00b6c055922e0ed2d88efdd252b2fb64': 1,
#  '00b6e66f005a657a6b13eedcacdf9342': 2,
#  '00b7174ea52bb811ebe2663add51afc0': 1,
#  '00b8d354b36820e9d6131fd5173c5581': 1,
#  '00b9e0f8f588d0406a3de447eb606970': 1,
#  '00ba414462370af2d76195d12e0d5481': 1,
#  '00ba57ae98928df6ba6ec9d3d8d4b1b7': 1,
#  '00bbc4179554524748f77763ddd62266': 1,
#  '00bc78808b22918a467b2fa4b8ef5d68': 1,
#  '00bcee890eba57a9767c7b5ca12d3a1b': 4,
#  '00bd2cb7e9076e1ccc9f766fc01a4cfd': 1,
#  '00bd50cdd31bd22e9081e6e2d5b3577b': 1,
#  '00bd8cf08fa3998ea6ad6d16c2165822': 1,
#  '00bdcdda88e6b02977fc6ce3d412c600': 1,
#  '00bdebefeb760588a3425fad9dfed3d9': 1,
#  '00beb247698c6aae94e3f859d279e2cd': 1,
#  '00bf1320ffb5fe47a845feca16c0e0b4': 1,
#  '00c00d5b36157595e21108ba1da2828f': 2,
#  '00c2335723b9b74668062e946dc66621': 1,
#  '00c405bd71187154a7846862f585a9d4': 1,
#  '00e6bc6b166eb28b4502c1cad4457248': 1,
#  '00e7aeced1d61792368ec7bf8b967a90': 1,
#  '00e7ee1b050b8499577073aeb2a297a1': 1,
#  '00ea33f994bec0bbfda582074083ae12': 1,
#  '00ea690fe8c5eba029a3884243a02352': 1,
#  '00eb7b95af5ed25aaec66d4ff5295846': 1,
#  '00ec95a58b63378d4cc06d196cdefdf6': 1,
#  '00ed64bc080d87b4ab7f0c433bc5e98f': 1,
#  '00eead1d5a799277ef3d6b387b0bebef': 1,
#  '00eef7fe9e315a85d1a61a50cccb2494': 1,
#  '00ef7ed06a55243f3e6a9d373a89eb14': 1,
#  '00efb72d8e18533f736e86770705d094': 1,
#  '00f1a34f176151c4dcbd802c244e1072': 1,
#  '00f1bb0af030935db1745ee28367ea26': 1,
#  '00f1c7c1542f5f86c3091749d9e939d8': 1,
#  '00f1cc7439ccb8671133776d1829faf5': 4,
#  '00f251b943aba645652c7138e4716fee': 1,
#  '00f2a3509bd600bd1a06a48353788d93': 1,
#  '00f2c876aa08fbba04199823952e96c1': 1,
#  '00f324f6ec332cd73ef8be4888573662': 1,
#  '00f33ee62c15223679d3550e751c37cd': 1,
#  '00f426c7214575822c3cb44ea59ef0f6': 1,
#  '00f57f2ccce2a2e3f393fe8f5e616e0d': 1,
#  '00f5fbdc777e8198c1ee008122e28ae3': 1,
#  '00f621226c6f4e938348f6f3a71fdc62': 1,
#  '00f6ac4816d12f49026b09f2aa77d15f': 3,
#  '00f6dbc6195397197ee147ee45607a2c': 1,
#  '00f7c5b41250e0126ced62d612ff4711': 1,
#  '00f86b368251d739f1896d41469b2b7a': 3,
#  '00f8fc0cb9d9b7813f1f54fbd75426f1': 1,
#  '00f98eaeddb9debc8df8cb27e08216d4': 1,
#  '00f9b0236a85fb8a06fbd9b9c53fddd8': 1,
#  '00f9b6769c6648ac08bf43081d1f2b07': 1,
#  '00faa6afcde74aaa630e1d2fda2bb0f7': 1,
#  '00fb055886536063afa0dbee07a0944f': 2,
#  '00fb278a99144cc1004b3ed1452ff5e1': 1,
#  '00fbcd8b120e5706c58b9d1a0026a7da': 1,
#  '00fc308dd7f0937682698becaa9dcc45': 1,
#  '00fcf938cde49ae138942b632ed62393': 1,
#  '00fdb72e467da6f3b000b19b368a6cf6': 1,
#  '00fe20fc069833ab95021b46d6862646': 1,
#  '00fed9e582d5a3e38566872eec164ac6': 2,
#  '00ff0cf5583758e6964723e42f111bf4': 1,
#  '010061e3aa0c6ed5e393dda0652bbee8': 1,
#  '01006620eb4732deec44be4b0d9e33cd': 1,
#  '010078e0913f48d014483bd856c01ca1': 1,
#  '01015fb6493ea5b9ba105c80b5452da1': 1,
#  '0101aea69a09e1aa32caa6dbaba98503': 1,
#  '01029b44abe6e15c8df48b1b759ab437': 1,
#  '0103878b7ed86b6ec873cfae01379472': 1,
#  '01074135a88ffa5978eaadfc7f482f2b': 1,
#  '0108c64ec135e4a7a75e9b5102af9bfa': 1,
#  '0108fba93678555ad1cec9c267848187': 1,
#  '01094e169d4b14edaf6954eeddb83633': 1,
#  '010a35dc7fc3808a03d243d2fd8c6e35': 1,
#  '010ab3b1993057e91f825c672375a66d': 1,
#  '010b0f6bd323a9effd095a743e660f26': 1,
#  '010b143d83a59b355cd5a75c0f0fd785': 4,
#  '010c995323bc17d8156fbe2c37fed63e': 1,
#  '010d14f76a229c295260e4ca4744acc7': 1,
#  '010d15deea8cae96ae86ea8097917a17': 1,
#  '010d6db2f77220b394f147836c94f27b': 1,
#  '010e04b5f879320f29a9bd6ca41abc94': 1,
#  '010e7dda85fff564e8b7076ae3928efb': 2,
#  '010ef5b0279d7512e7343cb775e423c0': 1,
#  '010efe60bdadc9261d1902f3c1dda5f3': 1,
#  '010f223ddbec749e95ef3f5414f9c4ee': 1,
#  '010fadb12341d8253d920362fc8f7a16': 1,
#  '010ff1cfe12f3094577e72b7bcecdf98': 1,
#  '0110688c40ff035d672af3aac1f38f10': 1,
#  '011080783e02d05b26c8c158b3653a42': 1,
#  '011105c3b5b8693eda1bfb1f152cec2a': 1,
#  '011108c8a3d6eee6807f48a2e639439f': 1,
#  '01115c06246220def210911556bdc0e5': 2,
#  '011331376a4c6cc7a9e5bc165ec169d0': 1,
#  '011375f941b3695c3c3ee58bfe0d3655': 1,
#  '0113affd907a209209ab08413bb54226': 1,
#  '0113c9989fe6e5007795daec0633b405': 2,
#  '011405ae7b89def8ffb3468eb29c299d': 1,
#  '01144cadcf64b6427f0a6580a3033220': 2,
#  '0114835d7f0b3f674b70a989411e31c1': 1,
#  '01156b662f3f47b249b5a8881d205f08': 1,
#  '0115abf6b892040abfdd5bdfcb6b2c51': 1,
#  '0115d160c5fbd758a139ff90821db60d': 1,
#  '0115f8bb1dc16d3fac863ce1deb037b6': 1,
#  '011667ae100a333a3051c9a23e3f0283': 1,
#  '011724d1afbd91844302627f79a66800': 1,
#  '0119e98feb97441cb456c010c25b04ff': 1,
#  '011a43bc9bb525517251ebb3ebc99b69': 1,
#  '011a56023faf5bbb9af634e20a85f7bc': 1,
#  '011abf147a69ba486bae3a74b6cd1814': 1,
#  '011af0959ebf2b09a062867811dc63b5': 1,
#  '011b142c9e082a5c1d10e0a88cd9c8e8': 1,
#  '011b8dd4f8c36fd4fcf50643ce91d58a': 1,
#  '011bf86f1b7dacebda2c874333cf656b': 2,
#  '011c899816ea29773525bd3322dbb6aa': 1,
#  '011e6e76dd0cd56d26b5b0cb036e80a8': 1,
#  '011f9dff2545a2cf8ac1809faed3ec88': 1,
#  '011fcb4fabb3e142579ad63472b11227': 1,
#  '0120e3dd2696a3bbb68dc2860815f7f2': 1,
#  '01218a8a807fc187849529e6f12237a9': 1,
#  '0121cfa7c946e6589f50d7012d3eb5eb': 1,
#  '012219b6d6d034eb359fc74730a080db': 1,
#  '012248555cb0bf51df99199cef81d562': 1,
#  '0122e81ff800460e44bb9c983ff2a2fd': 1,
#  '0123098b96f3d4014545642be53d891c': 1,
#  '01235dc626dcf13283207ba7f36a959a': 2,
#  '01237c761ffb72594a466ed514518af0': 1,
#  '0123a055aa66357326dd6db066592a7d': 2,
#  '014e78d1239f19fdcafd760d3e52f923': 1,
#  '014e7d12255fc66b5ea5e6c93eb4be7b': 1,
#  '014f1e63f9bd4f5578edcf4e5c305a0a': 1,
#  '014fc889637133d9075190ba873dfc03': 1,
#  '014ffbfe2df4c96a2b063d084583978f': 1,
#  '0150004d4d8eb63f9948de164da34e34': 1,
#  '01500f2503fa84279982d9d87750021a': 1,
#  '015183dcb37f19e0456905fa5aac0b69': 2,
#  '0152de20f6e09fb1133847df8babd490': 1,
#  '0152f10d04554388634b75f079f069fc': 1,
#  '015975a1ff4fdab8ae6f42eaaffd39fb': 1,
#  '0159b449009b3f8748ed7c56e9d84afe': 1,
#  '0159c6355a4e32f6ac68d838e2228150': 1,
#  '015a7c64361928a0782ec0e705174b6d': 1,
#  '015dd4d6681d1d15c0afebef64a0a092': 1,
#  '015e051dbb2407d4bd305635e46b732f': 1,
#  '015e6682b50c824bfdab6b866f937936': 1,
#  '015ed18d7ea7ca5c14f3c1decc55daf1': 1,
#  '015f079801c424fda3edc48be99267de': 1,
#  '015fb6b5f739788434fa690540f90f19': 2,
#  '01614e3e58906ab6c7e2f27e9b349f1a': 1,
#  '0161962c6c561d3acfaa3e2db9a14f96': 1,
#  '01625f404436eb3cb98cba1e9433db29': 1,
#  '01633cfec0376ac9f2606e271ede5574': 1,
#  '01643942766bdec224d5593041f714e6': 1,
#  '016495aaab3fb481dc9decab2b4fdbfb': 1,
#  '01667048de265bad400b945f29b52526': 1,
#  '0166ae6ff6d450bbac3eb4ed2885c0f8': 1,
#  '0166cc8756d58b4a30fb49de83527120': 1,
#  '016726239765c18f66826453f39c64e3': 1,
#  '016754282c7690ebd6658f9f8e0a49bb': 1,
#  '01677846a819fff5fc22d43d61e58367': 1,
#  '0167c361757c75999575cfdd8f8695f5': 1,
#  '0168a7f186c1f066748d15d8c51f489a': 1,
#  '01699d74ff89d35f15093f83d7783c39': 1,
#  '016a6dbc80aea6e2d217d2bedbc7b59e': 1,
#  '016a938f2b34aa5ef05027fc83f5b81b': 2,
#  '016b1af508245e59ef75d83e3fe20a92': 1,
#  '016b451bbcd4f0766dcbeb082cfe89db': 1,
#  '016befe103ce7c9e5b1b7ef359777eea': 1,
#  '016c6bb57a9de6b4e8f938fa6dde61b3': 1,
#  '016d1bdf6efab4f6b805df1c03043113': 1,
#  '016dee69b3de35a39bfccee5309307c3': 1,
#  '016e4acfc34b9f2abc69795f47c92f0e': 1,
#  '016f868b096c236312e8bcb818ccd11d': 1,
#  '016fbc333d66b414be541c6159576c40': 1,
#  '016ff85737c2072ab00a705cd8f87799': 1,
#  '0170e40334131d971605ae70efb33e4f': 1,
#  '0170fdd7ac7c7bbad5308207bd25a679': 1,
#  '0171835bbc71bcfacc26e9f59d56b62c': 1,
#  '01719300f9ca182b8361556a3873d8ed': 1,
#  '0171ca1dc94d8ebde8bbd3b686f44c41': 1,
#  '01721e0729fcb75ab238248fdbb48eeb': 1,
#  '01725657be56c432d5aaa2f914ae2c56': 1,
#  '0173932ad60ecb31c620fc523d9f40bd': 1,
#  '0173e291db71c3e688829f7f03e2d34a': 1,
#  '017499de14d22ef9e9a83ca54727480e': 2,
#  '0176a6846bcb3b0d3aa3116a9a768597': 1,
#  '0176d7e16d1bd14cde42d9d3a24e525b': 2,
#  '0176e50f3853fa068127afa3daff6402': 1,
#  '01786fff06f2f7e8a83950c4b3b424ea': 1,
#  '01787af385123b93ba50c5f05530ee12': 2,
#  '0178ff2480e2e8fb84d456dd3dc3d777': 2,
#  '0179a3003c894f1dd3b1ddda5d1f8a12': 2,
#  '017b11be3048fdfb58e63edc5fc8f4b8': 1,
#  '017b1d6881222283afdc50baf3dcb0d5': 1,
#  '017b84f6bee0e4287eb8a8c9f5df549e': 1,
#  '017c16deefc1868a33a5966485ea4721': 1,
#  '017c9c82265e832840e4209750680e94': 1,
#  '017cf0b342401318dcaeb25478e13a6f': 1,
#  '017dcb6892d4469a13dee34f241f8c4e': 2,
#  '0180ebc47853bfc5997af28f5a7e8849': 1,
#  '0181409c6498f79e161dde79c2a7dc59': 1,
#  '01825d0debce07b6502f4aff38a00e69': 1,
#  '0182f6cbb4fb10918a76485fc92d7c49': 1,
#  '01835ef41c5ac66dd9ec6084fa1d0533': 1,
#  '0184d4ddb259e1a4cfc2871888cf97b8': 1,
#  '01855f880aae9a984c7c33b26fcf2e02': 2,
#  '018778568fad26695334c784563c08d4': 1,
#  '01882618ede11253381513166b49429e': 1,
#  '0188777fe321843a18be24a6e9aa1e53': 1,
#  '0188ca1fe398161f0f310fec985ac155': 1,
#  '018bb1508d9156b81990407b91fb35a8': 2,
#  '018cb6a10649393055c272ba2984e8bb': 1,
#  '018fb228a3dd1a16349e73d2e41b239d': 1,
#  '01908071e35fdc75bc0d7764f153abc2': 1,
#  '0190e75feb05f78ccb1b56853ca4f6cb': 1,
#  '0191b6a5a70bcbc6cdd39427f216602e': 1,
#  '0191bbb5166d4b9a68df11797d5acfa9': 1,
#  '0191ee5deb2474bc1f4189fa709289b2': 2,
#  '0193517cd10a54473b6fd8392b58313f': 1,
#  '0193a99edc8c599aaa16f9b9e991efb8': 1,
#  '019440e41e276668d99d996d5d1a22c1': 1,
#  '0194686a55eb0a869321fb107f4d114a': 1,
#  '01946da9e2db8bab61d79296c037ee1f': 1,
#  '019536ad39a0dea8bb75c00359a0386b': 1,
#  '019543c0de8386be97738b589ee695aa': 1,
#  '019636907d07b2433be000d9d6bed153': 1,
#  '0197416059c0e56b5344bf2188066317': 1,
#  '01978b8bae8292ffb4cee6abdf9b9089': 1,
#  '0197cb265e2c84b9f89dfd784095d2f6': 1,
#  '019886de8f385a39b75bedbb726fd4ef': 1,
#  '01988bf5b8acbc4d6ced86e4d47fcb1a': 1,
#  '0198c71148c2e08c7c52b860f640fa4e': 1,
#  '0198e0de42189b3941d46857a87fac91': 1,
#  '0199115a1cbfc272c5bd53117772a64a': 1,
#  '0199edc5b01351df8e73a674aa473ee7': 1,
#  '019a242bea1553b3b7e12bc38cb57a23': 1,
#  '019aaee09698daf81dcffe9d94a18b5c': 1,
#  '019b02e139cfcd97f93366f7a38f5695': 1,
#  '019b8e16e30c8b9ad9bf87e039a27765': 1,
#  '019bdbaef5b5121c9b1811976aa510a5': 2,
#  '019c4b64cf3d733807ef5bc8bcf6d123': 1,
#  '019ccfeea1ea9afbebdad57d65f2e36f': 1,
#  '019d029f0b101343d44017d249b1f64f': 1,
#  '019d444bd00f1ccb4643de466f9a1525': 1,
#  '019d79b37e56c6d56d6323fed0c54d70': 1,
#  '019e03014ec20cc2e3b180cdcf90b4e8': 1,
#  '019edbdfeb6923e55558362c2b84ec37': 1,
#  '01a0013ddc7cd129e350e8671b56a263': 3,
#  '01a1553cddb473cec004af5ce2192f1c': 1,
#  '01a15ee6a1b9050e7678b72cb4c3b486': 1,
#  '01a1969ee54e7016bcc0cfeb4fa8c634': 1,
#  '01a26a995dcef1d58bdee5b8862c7a02': 1,
#  '01a3ee1c837fb57db23d898f0eb5111d': 1,
#  '01a49649881d677e0c901ca0f6564382': 1,
#  '01a4ec962d7589584c11650ca20d728b': 2,
#  '01a6ad782455876aa89081449d49c452': 1,
#  '01a75ac3dd000b7628a684be97c29234': 1,
#  '01a921eb5bf5df0c2990e62563ceca49': 2,
#  '01a9d731c0f08f4f79c10b7679dcdebf': 1,
#  '01aa38b66d95377a4f276f78742aca15': 1,
#  '01ac6cbac1cda667c97d35046b75668f': 1,
#  '01ad4f241a16bff724de081b558f0f4d': 1,
#  '01ae5e4c5d2549f7c05000a2f5856c28': 1,
#  '01ae629e578b0eb0935ea1ce19c409f1': 1,
#  '01af7745a283aeb0f0754495c4b51ac7': 1,
#  '01b02139ac5f79a5de2c56284af7bb3e': 1,
#  '01b06b4d63c340902dbe3d9f8b2fe821': 2,
#  '01b15a896c5842077af2aaf4a9f94309': 1,
#  '01b1800f51715ab76f67caf732206437': 1,
#  '01b1a7fdae9ad1837d6ab861705a1fa5': 2,
#  '01b241fa1421c8284e8c1029a503360f': 1,
#  '01b276e7af1d9e3ed34b431d39f45fa1': 1,
#  '01b2dd042de98a15b6a9a141bf71c344': 1,
#  '01b330808c5819a6a3cb79b72f0b8288': 1,
#  '01b37f50cf3098b3dd9d0450a188348c': 1,
#  '01b4a2ad3420c19a1c7c402513e7725c': 1,
#  '01b4dfef1c8848e8c0431ce17f5f72ea': 1,
#  '01b538a0b1a9eeecdfbc03223190e4bf': 1,
#  '01b6bbf0a9ac5d54dfebb11ddcd8fa8e': 1,
#  '01b6d15407d425529cbf0ec96258cb84': 1,
#  '01b703d8365608f2b01ed9c076d0b3dc': 1,
#  '01b84214591ddd4edad9fa4a1f344f84': 1,
#  '01b94d6940365deb1eedb643ba43114a': 1,
#  '01ba495d945c6a1c5b198bbad63e61c6': 1,
#  '01ba72e24cf883d74c5479c0a626c740': 1,
#  '01ba82170ebb683c73793bb809bbf1b9': 3,
#  '01ba9a2e5dcc1568b55695106d677b0c': 2,
#  '01bae920aea13b891b50bc1543634a65': 1,
#  '01bb52d7a8dffb8bef5b79268487cd10': 1,
#  '01bb5b3cb7df4da98ea2214d083784c4': 1,
#  '01bbf0fb0773cef52b4d6501e83162f3': 1,
#  '022e34b10acb0f74f51f03b3bf8d996d': 1,
#  '022e89c60857b5c81788e7e09d04b3ef': 1,
#  '022f80b8a6f58b11018082b505f15c38': 1,
#  '0231382a78f19752dabca6a86b618152': 1,
#  '0231a1f06afc507072e11f93fa6e736b': 1,
#  '0231f6b89e5798ff6c0dfb1e18a94da9': 1,
#  '0232512713ff84ce6ae5c96971894149': 1,
#  '02332b54c758506809fd87d9c2748086': 1,
#  '02333096645cf1743050acd043b76e69': 1,
#  '02342201aaaf713fa9f51c6d44444424': 1,
#  '02346f2f5b8930a992461a607bf6bf62': 1,
#  '02346fd715e28d8e4fdb6893cd121f71': 1,
#  '02355020fd0a40a0d56df9f6ff060413': 1,
#  '02358a9949662b292e80635305dea78b': 1,
#  '023669233121f0fb7899e5be2b22885f': 3,
#  '0236711b7bfcba7479639be980c21128': 1,
#  '023a60303ff8d9e08b99e7474f7416ce': 1,
#  '023aa4b0585594124bc50e55e0e11a5f': 1,
#  '023ae47e11483bdb8aa35fa4662aee1c': 1,
#  '023af4b88d12c9f3f56bcb55da0450c5': 2,
#  '023b3575b6649cf01cb239c0e9603262': 1,
#  '023b49300b34f2b9961857266df731dc': 1,
#  '023dced8c25f743c5fdcf14edabac7a8': 1,
#  '023dec08929b8cafa8028da5e6b527b6': 1,
#  '023e55afed85f9778758fba7752a9215': 1,
#  '023efd060c082063e299dc77891ea1b7': 1,
#  '023faf5fac58639f7cf53cb7dd219859': 1,
#  '0240111ef6f94ee97599bd002acec1cd': 1,
#  '0240c9d87266e4cabc3bacdcdc6e77e4': 1,
#  '0241b276e1e2b1d6873473c44240b426': 1,
#  '024319cfbf2156b9b8a0a50c3aef45b7': 1,
#  '02440f65dc09737b491463739c347446': 1,
#  '02447024ad7cd72fab1af9b28bebb901': 1,
#  '024554aeb0da84476f1c31a711e0990c': 2,
#  '0245631f7bd55dbee7c6b441629bba94': 4,
#  '02457250c331120c9dea3bf840316d54': 1,
#  '0245af1fbe1f70f5ac7c1793c78f12cb': 1,
#  '024602a52e3c89ca5f963affcd2bedad': 1,
#  '0246b043b8ae041912cc7651ceb1ba2f': 1,
#  '0247aa98317f60908e99f44e7a2a4896': 1,
#  '0248cb6c91b223b74dc554e1d2c2a59d': 1,
#  '024a19cc498cc1a9efcf675d1ca465c3': 1,
#  '024a74550cdbd36c0fe3955fc9e2bcf0': 1,
#  '024ab991361d48e491b7dad2f172b43f': 1,
#  '024b3b6b53b99a1eb8b9b34515106765': 1,
#  '024bee763e8abbf0cd46fa7f440c41ea': 2,
#  '024d4903890a56c2e98df63a32206bd9': 1,
#  '024d4ef645f204e4f95cb2a0d9cc61f9': 2,
#  '024d56279184e5cb942d9abf28fc14e6': 1,
#  '024f8681c73783017f7cd5d5b061be3a': 1,
#  '02504308041b6ad0a112b2b7159439ed': 2,
#  '0250c3964e5ca77ecac2db28d78aa89f': 1,
#  '02521a906b13fc8ff9314bf88adc31ed': 1,
#  '0252299d97791cd5879873cba920d1f7': 1,
#  '025321e4e9674e090b7bc101f9c5ab5a': 1,
#  '029b1d3a355dec12cfed60927f076a9d': 2,
#  '029b2daf51dda061aeb1cf32c9306db7': 1,
#  '029b99b0436c25c8de22cb828831ffa8': 1,
#  '029c366599ce117100419a093b7f6132': 1,
#  '029c545413b10a6bd7540401f6eef0a3': 1,
#  '029de66f2ffa0e793ca2aad5e304a748': 1,
#  '029e3b4c8e64bea4ba22e456cd1930a3': 1,
#  '029e9be2972cf662f2cb336e98872ae3': 1,
#  '029f37989dcd7c9b928028086d68034b': 1,
#  '029f7a5aabaadfcdfe8c0eddb59a1069': 2,
#  '02a001cb5f40b1fee4f0375c89cce463': 2,
#  '02a059e99249511338c51476bf3d942e': 1,
#  ...}

# %%
order_item_beta['order_item_id'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  8,  7, 20, 12, 10, 13, 15, 11, 14, 21,  9])

# %%
dic_ord_pr={}
column_new_ids=[]
column_new_items=[]
keys_id=list(new_df_olist_order['order_id'].unique())




new_id=df_olist_orders[df_olist_orders['order_id'].isin(keys_id)]
list_ids=list(new_df_olist_order['order_id'])
#l1=len(new_df_olist_order['order_id'])
#l2=len(new_id['order_id'])
#print(l1)
#print(len(list_ids))
for count2, ids_ in enumerate(list_ids):
    dic_ord_pr[ids_]=new_df_olist_order['product_category_name'][count2]
    
for  keys1 in list(new_id['order_id']):
    column_new_ids.append(dic_ord_pr[keys1])
    column_new_items.append(dict_item[keys1])
new_df_id=new_id.copy()
new_df_id['product_category_name']=column_new_ids
new_df_id['order_item_id']=column_new_items

new_df_id["order_delivered_carrier_date"]=pd.to_datetime(new_df_id['order_delivered_carrier_date'])
new_df_id['order_delivered_customer_date']=pd.to_datetime(new_df_id['order_delivered_customer_date'])
new_df_id['order_estimated_delivery_date']=pd.to_datetime(new_df_id['order_estimated_delivery_date'])
new_df_id['order_approved_at']=pd.to_datetime(new_df_id['order_approved_at'])
new_df_id['order_purchase_timestamp']=pd.to_datetime(new_df_id['order_purchase_timestamp'])
new_df_id['difference']=new_df_id['order_delivered_customer_date']-new_df_id['order_delivered_carrier_date']
new_df_id['order_purchase_timestamp']=pd.to_datetime(new_df_id['order_purchase_timestamp'])
new_df_id["year_purchase"]=new_df_id["order_purchase_timestamp"].dt.year
#len(dic_ord_pr.keys())
#len(list_ids)
new_df_id
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...            ...                      ...                 ...
# 99436    delivered      2017-03-09 09:54:05 2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date   product_category_name  order_item_id  \
# 0                        2017-10-18   utilidades_domesticas              1
# 1                        2018-08-13              perfumaria              1
# 2                        2018-09-04              automotivo              1
# 3                        2017-12-15                pet_shop              1
# 4                        2018-02-26               papelaria              1
# ...                             ...                     ...            ...
# 99436                    2017-03-28            beleza_saude              1
# 99437                    2018-03-02                   bebes              1
# 99438                    2017-09-27      eletrodomesticos_2              1
# 99439                    2018-02-15  informatica_acessorios              2
# 99440                    2018-04-03            beleza_saude              1
#
#             difference  year_purchase
# 0      6 days 01:30:13           2017
# 1     12 days 00:56:45           2018
# 2      9 days 04:16:29           2018
# 3      9 days 10:48:43           2017
# 4      1 days 22:30:28           2018
# ...                ...            ...
# 99436  7 days 03:49:58           2017
# 99437 20 days 18:15:14           2018
# 99438 23 days 14:31:51           2017
# 99439 13 days 07:57:51           2018
# 99440  6 days 14:56:31           2018
#
# [98666 rows x 12 columns]

# %%
new_df_id['difference']=new_df_id['difference'].dt.days

# %%
new_df_id.groupby(['product_category_name'])['difference'].describe()
# Out:
#                             count      mean        std  min  25%  50%    75%  \
# product_category_name
# agro_industria_e_comercio   177.0  7.909605   7.216047  0.0  3.0  6.0  11.00
# alimentos                   437.0  7.418764  10.696648  0.0  2.0  5.0   9.00
# alimentos_bebidas           220.0  7.490909   7.201909  0.0  3.0  5.0   9.25
# artes                       192.0  6.838542   6.371564  0.0  2.0  5.5  10.00
# artes_e_artesanato           22.0  3.136364   3.655335  0.0  1.0  2.0   4.75
# ...                           ...       ...        ...  ...  ...  ...    ...
# sinalizacao_e_seguranca     137.0  7.240876   9.615035  0.0  2.0  5.0  10.00
# tablets_impressao_imagem     78.0  8.961538   7.025819  0.0  5.0  7.5  12.00
# telefonia                  4083.0  8.979182   8.590773  0.0  3.5  7.0  12.00
# telefonia_fixa              210.0  8.276190   7.003069  0.0  4.0  6.0  11.00
# utilidades_domesticas      5682.0  7.605773   8.026261 -8.0  3.0  6.0  10.00
#
#                              max
# product_category_name
# agro_industria_e_comercio   42.0
# alimentos                  138.0
# alimentos_bebidas           46.0
# artes                       42.0
# artes_e_artesanato          17.0
# ...                          ...
# sinalizacao_e_seguranca     95.0
# tablets_impressao_imagem    39.0
# telefonia                  165.0
# telefonia_fixa              40.0
# utilidades_domesticas      178.0
#
# [73 rows x 8 columns]

# %%
new_df_id.groupby(['product_category_name'])['order_item_id'].describe()
# Out:
#                             count      mean       std  min  25%  50%  75%  \
# product_category_name
# agro_industria_e_comercio   182.0  1.164835  0.626553  1.0  1.0  1.0  1.0
# alimentos                   446.0  1.143498  0.521054  1.0  1.0  1.0  1.0
# alimentos_bebidas           226.0  1.243363  0.691584  1.0  1.0  1.0  1.0
# artes                       199.0  1.050251  0.385976  1.0  1.0  1.0  1.0
# artes_e_artesanato           22.0  1.090909  0.294245  1.0  1.0  1.0  1.0
# ...                           ...       ...       ...  ...  ...  ...  ...
# sinalizacao_e_seguranca     139.0  1.424460  0.977859  1.0  1.0  1.0  1.0
# tablets_impressao_imagem     78.0  1.076923  0.268194  1.0  1.0  1.0  1.0
# telefonia                  4189.0  1.087610  0.449144  1.0  1.0  1.0  1.0
# telefonia_fixa              215.0  1.218605  0.828030  1.0  1.0  1.0  1.0
# utilidades_domesticas      5823.0  1.195604  0.697718  1.0  1.0  1.0  1.0
#
#                             max
# product_category_name
# agro_industria_e_comercio   6.0
# alimentos                   6.0
# alimentos_bebidas           5.0
# artes                       6.0
# artes_e_artesanato          2.0
# ...                         ...
# sinalizacao_e_seguranca     6.0
# tablets_impressao_imagem    2.0
# telefonia                  14.0
# telefonia_fixa              8.0
# utilidades_domesticas      12.0
#
# [73 rows x 8 columns]

# %%
mean_day=prd_mean=new_df_id.groupby(['product_category_name'])['difference'].mean().reset_index(name="mean_days").sort_values('mean_days', ascending=True)

# %%
mean_day_top_ten = mean_day.head(10)
mean_day_top_ten
plt.figure(figsize=(16, 6))
plt.xticks(rotation=90)
sns.barplot(x='product_category_name', y='mean_days', data=mean_day_top_ten,  ci=None);

# %%
s=new_df_id.groupby(['product_category_name','order_status'])['order_id'].count().reset_index(name="count").sort_values('count',ascending=False)
s.head(60)
#k=s.plot(x="order_status", y="count", rot=90)
#new_df_id.groupby(['product_category_name'])['order_status'].count().reset_index(name="count").sort_values('count', ascending=False)
# Out:
#                               product_category_name order_status  count
# 53                                  cama_mesa_banho    delivered   9179
# 43                                     beleza_saude    delivered   8615
# 122                                   esporte_lazer    delivered   7498
# 165                          informatica_acessorios    delivered   6508
# 204                                moveis_decoracao    delivered   6194
# 270                           utilidades_domesticas    delivered   5682
# 250                              relogios_presentes    delivered   5477
# 260                                       telefonia    delivered   4083
# 27                                       automotivo    delivered   3785
# 48                                       brinquedos    delivered   3779
# 95                                       cool_stuff    delivered   3517
# 152                              ferramentas_jardim    delivered   3410
# 234                                      perfumaria    delivered   3072
# 33                                            bebes    delivered   2760
# 111                                     eletronicos    delivered   2504
# 224                                       papelaria    delivered   2248
# 127                     fashion_bolsas_e_acessorios    delivered   1812
# 240                                        pet_shop    delivered   1679
# 209                               moveis_escritorio    delivered   1248
# 187                                malas_acessorios    delivered   1014
# 73                                   consoles_games    delivered   1014
# 104                                eletrodomesticos    delivered    747
# 78                construcao_ferramentas_construcao    delivered    730
# 170                           instrumentos_musicais    delivered    607
# 117                                 eletroportateis    delivered    605
# 179                          livros_interesse_geral    delivered    494
# 61                                  casa_construcao    delivered    474
# 4                                         alimentos    delivered    437
# 218                                     moveis_sala    delivered    401
# 57                                    casa_conforto    delivered    363
# 24                                            audio    delivered    346
# 39                                          bebidas    delivered    283
# 192                                    market_place    delivered    267
# 183                                 livros_tecnicos    delivered    253
# 69                                     climatizacao    delivered    245
# 199  moveis_cozinha_area_de_servico_jantar_e_jardim    delivered    237
# 132                                fashion_calcados    delivered    235
# 84                construcao_ferramentas_iluminacao    delivered    235
# 160                   industria_comercio_e_negocios    delivered    230
# 108                              eletrodomesticos_2    delivered    227
# 8                                 alimentos_bebidas    delivered    220
# 265                                  telefonia_fixa    delivered    210
# 13                                            artes    delivered    192
# 87                    construcao_ferramentas_jardim    delivered    187
# 230                                             pcs    delivered    177
# 0                         agro_industria_e_comercio    delivered    177
# 91                 construcao_ferramentas_seguranca    delivered    155
# 255                         sinalizacao_e_seguranca    delivered    137
# 20                                 artigos_de_natal    delivered    125
# 148                  fashion_underwear_e_moda_praia    delivered    117
# 46                                     beleza_saude      shipped    107
# 144                         fashion_roupa_masculina    delivered    106
# 56                                  cama_mesa_banho      shipped    106
# 82               construcao_ferramentas_ferramentas    delivered     97
# 125                                   esporte_lazer      shipped     95
# 213                                   moveis_quarto    delivered     88
# 258                        tablets_impressao_imagem    delivered     78
# 207                                moveis_decoracao      shipped     76
# 273                           utilidades_domesticas      shipped     76
# 168                          informatica_acessorios      shipped     75

# %% [markdown]
# ## Table purchased UK #

# %%
#DataSet Retailer Pricing
# 15- UK_retail_transactions.csv
df_uk_retailer = pd.read_csv("./e-commerce/datasets/UK_reail/UK_retail_transactions.csv")
df_uk_retailer["invoice_date"] = pd.to_datetime(df_uk_retailer["invoice_date"])
df_uk_retailer["Year"] = df_uk_retailer["invoice_date"].dt.year
df_uk_retailer["Month"] = df_uk_retailer["invoice_date"].dt.month
df_uk_retailer["Total_Value"] = df_uk_retailer["price"] * df_uk_retailer["quantity"]
df_uk_retailer["Order_Status"]= np.where((df_uk_retailer["quantity"] <= 0)|(df_uk_retailer["price"] <= 0), "Returned", "Delivered")
df_uk_retailer.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1     489434     79323P                   PINK CHERRY LIGHTS        12
# 2     489434     79323W                  WHITE CHERRY LIGHTS        12
# 3     489434      22041         RECORD FRAME 7" SINGLE SIZE         48
# 4     489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#          invoice_date  price  customerid         country  Year  Month  \
# 0 2009-12-01 07:45:00   6.95     13085.0  United Kingdom  2009     12
# 1 2009-12-01 07:45:00   6.75     13085.0  United Kingdom  2009     12
# 2 2009-12-01 07:45:00   6.75     13085.0  United Kingdom  2009     12
# 3 2009-12-01 07:45:00   2.10     13085.0  United Kingdom  2009     12
# 4 2009-12-01 07:45:00   1.25     13085.0  United Kingdom  2009     12
#
#    Total_Value Order_Status
# 0         83.4    Delivered
# 1         81.0    Delivered
# 2         81.0    Delivered
# 3        100.8    Delivered
# 4         30.0    Delivered

# %%
df_uk_retailer.shape
# Out:
# (1067371, 8)

# %%
df_uk_retailer['description'].unique()
# Out:
# array(['15CM CHRISTMAS GLASS BALL 20 LIGHTS', 'PINK CHERRY LIGHTS',
#        ' WHITE CHERRY LIGHTS', ..., 'mixed up',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df_uk_retailer['description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    5918
# REGENCY CAKESTAND 3 TIER              4412
# JUMBO BAG RED RETROSPOT               3469
# ASSORTED COLOUR BIRD ORNAMENT         2958
# PARTY BUNTING                         2765
#                                       ...
# samples                                  1
# CHROME EURO HOOK 20cm                    1
# MUG PINK AND PURPLE ARABIC DESIGN        1
# ACRYLIC BEAD CHAIN, PINK                 1
# wonky bottom/broken                      1
# Name: description, Length: 5698, dtype: int64

# %%
df_uk_retailer['country'].value_counts()
# Out:
# United Kingdom          981330
# EIRE                     17866
# Germany                  17624
# France                   14330
# Netherlands               5140
# Spain                     3811
# Switzerland               3189
# Belgium                   3123
# Portugal                  2620
# Australia                 1913
# Channel Islands           1664
# Italy                     1534
# Norway                    1455
# Sweden                    1364
# Cyprus                    1176
# Finland                   1049
# Austria                    938
# Denmark                    817
# Unspecified                756
# Greece                     663
# Japan                      582
# USA                        535
# Poland                     535
# United Arab Emirates       500
# Israel                     371
# Hong Kong                  364
# Singapore                  346
# Malta                      299
# Iceland                    253
# Canada                     228
# Lithuania                  189
# RSA                        169
# Bahrain                    126
# Brazil                      94
# Thailand                    76
# Korea                       63
# European Community          61
# Lebanon                     58
# West Indies                 54
# Bermuda                     34
# Nigeria                     32
# Czech Republic              30
# Saudi Arabia                10
# Name: country, dtype: int64

# %%
type(df_uk_retailer['quantity'][0])
# Out:
# numpy.int64

# %%
df_uk_retailer['total_price']=df_uk_retailer['quantity']*df_uk_retailer['price']
df_uk_retailer['year'].value_counts()
# Out:
# 2010    522714
# 2011    499429
# 2009     45228
# Name: year, dtype: int64

# %%
df_uk_retailer.pivot_table(index=['stock_code'], aggfunc='size').sort_values(ascending=False).reset_index().head(10)
# Out:
#   stock_code     0
# 0     85123A  5829
# 1      22423  4424
# 2     85099B  4216
# 3      21212  3318
# 4      20725  3259
# 5      84879  2960
# 6      47566  2768
# 7      21232  2747
# 8      22197  2549
# 9      22383  2540

# %%
df_uk_retailer['month']=df_uk_retailer['invoice_date'].dt.month
df_uk_retailer['month'].value_counts()
# Out:
# 11    162726
# 12    135758
# 10    119840
# 9      92317
# 3      78259
# 6      76857
# 7      72901
# 5      72353
# 8      68590
# 1      66702
# 4      63973
# 2      57095
# Name: month, dtype: int64

# %%
df_uk_retailer['day']=df_uk_retailer['invoice_date'].dt.day

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x='year', y='total_price', data=df_uk_retailer);

# %%
df_uk_retailer['quantity'].describe()
# Out:
# count    1.067371e+06
# mean     9.938898e+00
# std      1.727058e+02
# min     -8.099500e+04
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      1.000000e+01
# max      8.099500e+04
# Name: quantity, dtype: float64

# %%
sns.boxplot(x="year", y="quantity", data=df_uk_retailer[(df_uk_retailer["quantity"] >= 0) & (df_uk_retailer["quantity"] < 2500)]);

# %%
top_ten_uk_retailer = df_uk_retailer[(df_uk_retailer['quantity'] >= 0)].groupby('country')['quantity'].size().sort_values(ascending=False).head(10).reset_index()
plt.figure(figsize=(16, 6))
plt.ticklabel_format(style='plain', axis='x')
sns.barplot(x='quantity', y='country', data=top_ten_uk_retailer, orient='h', ci=None);

# %%
df_uk_retailer.describe().round(2)
# Out:
#          quantity       price  customerid        Year       Month  Total_Value
# count  1067371.00  1067371.00   824364.00  1067371.00  1067371.00   1067371.00
# mean         9.94        4.65    15324.64     2010.43        7.50        18.07
# std        172.71      123.55     1697.46        0.57        3.53       292.42
# min     -80995.00   -53594.36    12346.00     2009.00        1.00   -168469.60
# 25%          1.00        1.25    13975.00     2010.00        5.00         3.75
# 50%          3.00        2.10    15255.00     2010.00        8.00         9.90
# 75%         10.00        4.15    16797.00     2011.00       11.00        17.70
# max      80995.00    38970.00    18287.00     2011.00       12.00    168469.60

# %%
plt.figure(figsize=(16, 6))
plt.ticklabel_format(style='plain', axis='y')
df_uk_retailer[(df_uk_retailer['price'] >= 0) | (df_uk_retailer['quantity'] >= 0)]['price'].hist();

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x="Month", y="quantity", data=df_uk_retailer[(df_uk_retailer["quantity"] >= 0) | (df_uk_retailer["price"] >= 0)]);

# %%
top_ten_uk_retailer_product = df_uk_retailer[(df_uk_retailer['quantity'] >= 0) | (df_uk_retailer['price'] >= 0)].groupby('description')['quantity'].size().sort_values(ascending=False).head(10).reset_index()
plt.figure(figsize=(16, 6))
sns.barplot(x='quantity', y='description', data=top_ten_uk_retailer_product, orient='h', ci=None);

# %%
df_uk_retailer['Order_Status']= np.where((df_uk_retailer['quantity'] <= 0)|(df_uk_retailer['price'] <= 0), 'Returned', 'Delivered')

# %%
import warnings
warnings.filterwarnings("ignore")
categories = list(top_ten_uk_retailer_product["description"])
countries = ["United Kingdom", "EIRE", "Germany", "France", "Spain"]
top_ten_uk_value = df_uk_retailer[(df_uk_retailer["Order_Status"]=="Delivered") & (df_uk_retailer["description"].isin(categories))].groupby(["country","description"])["Total_Value"].size().sort_values(ascending=False).reset_index()
graph = sns.FacetGrid(top_ten_uk_value[top_ten_uk_value["country"].isin(countries)], col="country", palette="Set3", aspect=0.5, size=9)
graph.map(sns.barplot,"description","Total_Value")
graph.set_xticklabels(rotation=90)
plt.show();
